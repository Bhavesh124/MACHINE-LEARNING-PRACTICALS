# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Suyash\Downloads\insurance.csv")

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
#getting unique values for children feature
df.children.unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
#getting count for each values in children
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['sex'] = df['sex'].str.replace('female','0')
df['sex'] = df['sex'].str.replace('male','1')

# %%
df.sex.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df['sex'] = df['sex'].astype(float)

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.bmi.unique()
# Out:
# array([27.9, 33.8, 33. , 22.7, 28.9, 25.7, 33.4, 27.7, 29.8, 25.8, 26.2,
#        26.3, 34.4, 39.8, 42.1, 24.6, 30.8, 23.8, 40.3, 35.3, 36. , 32.4,
#        34.1, 31.9, 28. , 23.1, 32.8, 17.4, 36.3, 35.6, 28.6, 28.3, 36.4,
#        20.4, 20.8, 36.7, 39.9, 26.6, 36.6, 21.8, 37.1, 37.3, 38.7, 34.8,
#        24.5, 35.2, 33.6, 28.7, 37. , 31.8, 31.7, 22.9, 27.4, 33.7, 24.7,
#        25.9, 22.4, 39.1, 36.2, 24. , 24.8, 28.5, 28.1, 32. , 34. , 29.6,
#        35.5, 26.9, 38.3, 37.6, 41.2, 31.2, 27.2, 27. , 39.5, 31.3, 20. ,
#        19.3, 31.6, 25.5, 30.1, 29.9, 27.5, 28.4, 30.9, 35.1, 29.7, 35.7,
#        32.2, 49.1, 23.4, 29. , 31.4, 33.9, 28.8, 37.4, 17.8, 34.7, 26.5,
#        22. , 35.9, 25.6, 25.2, 32.5, 25.3, 38.8, 30.5, 37.7, 24.1, 24.4,
#        27.8, 36.9, 39.6, 28.2, 33.2, 18.9, 41.5, 30.3, 16. , 33.3, 29.2,
#        26.4, 30.7, 41.9, 32.1, 30.6, 18.1, 39.3, 36.1, 22.3, 26.7, 23.2,
#        38.1, 22.2, 38.4, 29.1, 22.1, 26.8, 30. , 20.9, 17.3, 34.2, 25.4,
# ...

# %%
#checking the datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   float64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   float64
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 73.3+ KB

# %%
df['smoker'] = df['smoker'].str.replace('yes','0')
df['smoker'] = df['smoker'].str.replace('no','1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df['smoker'] = df['smoker'].str.replace('yes','0')
#       2 df['smoker'] = df['smoker'].str.replace('no','1')
#
# NameError: name 'df' is not defined

# %%
df['smoker'] = df['smoker'].astype(float)

# %%
df.info()

# %%
df.dtypes
# Out:
# age           int64
# sex         float64
# bmi         float64
# children      int64
# smoker      float64
# region       object
# expenses    float64
# dtype: object

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data = df.copy()
data.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19  0.0  27.9         0     0.0  southwest  16884.92
# 1   18  1.0  33.8         1     1.0  southeast   1725.55
# 2   28  1.0  33.0         3     1.0  southeast   4449.46
# 3   33  1.0  22.7         0     1.0  northwest  21984.47
# 4   32  1.0  28.9         0     1.0  northwest   3866.86

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.665471     1.094918     0.795217
# std      14.049960     0.500160     6.098382     1.205493     0.403694
# min      18.000000     0.000000    16.000000     0.000000     0.000000
# 25%      27.000000     0.000000    26.300000     0.000000     1.000000
# 50%      39.000000     1.000000    30.400000     1.000000     1.000000
# 75%      51.000000     1.000000    34.700000     2.000000     1.000000
# max      64.000000     1.000000    53.100000     5.000000     1.000000
#
#            expenses
# count   1338.000000
# mean   13270.422414
# std    12110.011240
# min     1121.870000
# 25%     4740.287500
# 50%     9382.030000
# 75%    16639.915000
# max    63770.430000

# %%
data.cov()
# Out:
#                    age         sex           bmi    children       smoker  \
# age         197.401387   -0.146559      9.368560    0.719303     0.141903
# sex          -0.146559    0.250160      0.141467    0.010348    -0.015383
# bmi           9.368560    0.141467     37.190265    0.092958    -0.009769
# children      0.719303    0.010348      0.092958    1.453213    -0.003734
# smoker        0.141903   -0.015383     -0.009769   -0.003734     0.162969
# expenses  50874.802133  347.014516  14665.149703  992.674243 -3848.667030
#
#               expenses
# age       5.087480e+04
# sex       3.470145e+02
# bmi       1.466515e+04
# children  9.926742e+02
# smoker   -3.848667e+03
# expenses  1.466524e+08

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
df.age.unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
features = df.columns
features
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  sex   bmi  children  smoker     region  expenses
# 0      19  0.0  27.9         0     0.0  southwest  16884.92
# 1      18  1.0  33.8         1     1.0  southeast   1725.55
# 2      28  1.0  33.0         3     1.0  southeast   4449.46
# 3      33  1.0  22.7         0     1.0  northwest  21984.47
# 4      32  1.0  28.9         0     1.0  northwest   3866.86
# ...   ...  ...   ...       ...     ...        ...       ...
# 1333   50  1.0  31.0         3     1.0  northwest  10600.55
# 1334   18  0.0  31.9         0     1.0  northeast   2205.98
# 1335   18  0.0  36.9         0     1.0  southeast   1629.83
# 1336   21  0.0  25.8         0     1.0  southwest   2007.95
# 1337   61  0.0  29.1         0     0.0  northwest  29141.36
#
# [1338 rows x 7 columns]>

# %%
df.smoker.unique()
# Out:
# array([0., 1.])

# %%
num_fea = [fea for fea in features if df[fea].nunique()!=4]
num_fea
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'expenses']

# %%
cat_fea = [fea for fea in features if df[fea].nunique()==4]
cat_fea
# Out:
# ['region']

# %%
import scipy.stats as stats

# %%
for i in num_fea:
    plt.figure(figsize=(15,6))
    plt.subplot(121)
    sns.histplot(data=data,x=i,kde=True,bins=30)
    plt.title("{}'s Distribution".format(i),fontweight='bold',fontsize=15)
    
    plt.subplot(122)
    stats.probplot(df[i],dist='norm',plot=plt)
    plt.title("{} Q-Q plot".format(i),fontweight='bold')

# %%
sns.histplot(df.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.countplot(data=data,x='age',hue='smoker')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(df.smoker,hue=df.sex)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.barplot(df.children,df.bmi)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='bmi'>

# %%
sns.countplot(df.children,hue=df.smoker)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
sns.countplot(df.region,hue=df.smoker)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sns.scatterplot([i for i in range(df.shape[0])],df.expenses)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='expenses'>

# %%
sns.histplot(df.expenses)
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='Count'>

# %%
sns.barplot(df.smoker,df.expenses)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='expenses'>

# %%
df.value_counts(df.smoker)
# Out:
# smoker
# 1.0    1064
# 0.0     274
# dtype: int64

# %%
sns.barplot(df.smoker,df.bmi)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='bmi'>

# %%
sns.countplot(df.expenses)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='expenses', ylabel='count'>

# %%
sns.barplot(df.children,df.expenses,hue=df.smoker)
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='expenses'>

# %%
sns.pairplot(df)

# %%
df.age.unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
sns.catplot(data=data,x='children',y='age',hue='sex',kind='swarm') #female:0,male:1
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 47.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=data,x='smoker',y='age')

# %%
sns.catplot(data=data,x='children',y='smoker')

# %%
sns.catplot(data=data,x='children',y='age',hue='sex',kind='box')

# %%
for fea in num_fea:
    sns.countplot(data=data,x=fea,hue='smoker')
    plt.show()

# %%
sns.catplot(data=data,x='children',y='region',hue='smoker',kind='swarm')
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=data,x='region',y='age',hue='smoker',kind='swarm')
# Out:
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Suyash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
